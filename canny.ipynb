# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('fish.jpg')

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
plt.show()

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_image, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()

# %%
edges = cv2.Canny(gray_image, 100, 200)

# %%
plt.imshow(edges, cmap='gray')
plt.title('Canny Edge Detection')
plt.axis('off')
plt.show()

# %%
blurred_image = cv2.GaussianBlur(image, (11, 11), 0)

# %%
plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
plt.title('Blurred Image')
plt.axis('off')
plt.show()

# %%
gray_image.shape
# Out:
# (980, 1473)

# %%
edges=cv2.Canny(image=gray_image,threshold1=115,threshold2=115)

# %%
plt.imshow(edges)

# %%
import numpy as np
medium=np.median(image)
medium
# Out:
# np.float64(0.0)

# %%
low=int(max(0,0.7*medium))
high=int(max(255,1/3*medium))

# %%
low
# Out:
# 0

# %%
high
# Out:
# 255

# %%
Canny_edges_blur=cv2.Canny(blurred_image,threshold1=low, threshold2=high)

# %%
plt.imshow(Canny_edges_blur,cmap='gray')
